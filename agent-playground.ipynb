# %%
from dotenv import load_dotenv

load_dotenv()

# %%
from agent import agente_rag
from runtime_context import RAGContext
from langchain_core.messages import HumanMessage, AIMessage, ToolMessage

# %%
agente_rag.invoke(
  {"messages": [HumanMessage(content="How to prepare students")]},
  context=RAGContext(file_id="1xVTddLa6Ut_JP-6VyhSc7eslgIWLNtED"),
)
# Out:
# {'messages': [HumanMessage(content='How to prepare students', additional_kwargs={}, response_metadata={}, id='61cbf34e-c8d7-4ec5-831c-a1bed9ba7214'),
# ...
